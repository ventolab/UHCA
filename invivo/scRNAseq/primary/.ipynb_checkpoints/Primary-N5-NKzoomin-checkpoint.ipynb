# %%
# Integration of biopsies and organ donors from 2 studies
import anndata, numpy as np, pandas as pd, imp, lpy, scanpy as sc
sc.logging.print_versions()
# Out:
# scanpy==1.5.1 anndata==0.7.4 umap==0.4.6 numpy==1.19.1 scipy==1.5.2 pandas==1.0.5 scikit-learn==0.23.2 statsmodels==0.11.1 python-igraph==0.8.2 louvain==0.6.1 leidenalg==0.8.1

# %%
# Set some constants
adata = anndata.read_h5ad("N4-integrated_donors.h5ad")

# %%
# Integrate the Endothelial cell fraction specifically
# Use sample for batch correction, and integrate all genes
das = lpy.scvi_prepare(adata, "SampleID", [x not in ["filtered", "doublets"] for x in  adata.obs["subcluster_immune"] ], nbgenes = 0, min_cell_threshold= 2, doinspect=True)
# Out:
# Prepare Data for Scvi/TotalVi
# def scvi_prepare(anndatapath, field, cellfilter = None, nbgenes = 5000, genes_to_filter= None, use_ccfilter_prefix=None, citeseqkey = "protein_expression", use_raw_slot_instead =None, min_cell_threshold= 0, doinspect=False):
#     if doinspect is True: print("\033Prepare Data for Scvi/TotalVi\033\033"); print(inspect.getsource(scvi_prepare));print("\033Execution:\033")
#     if use_ccfilter_prefix is not None :
#         genes_to_filter = [use_ccfilter_prefix + x for x in ["HMGB2","CDK1","NUSAP1","UBE2C","BIRC5","TPX2","TOP2A","NDC80","CKS2","NUF2","CKS1B","MKI67","TMPO","CENPF","TACC3","FAM64A","SMC4","CCNB2","CKAP2L","CKAP2","AURKB","BUB1","KIF11","ANP32E","TUBB4B","GTSE1","KIF20B","HJURP","CDCA3","HN1","CDC20","TTK","CDC25C","KIF2C","RANGAP1","NCAPD2","DLGAP5","CDCA2","CDCA8","ECT2","KIF23","HMMR","AURKA","PSRC1","ANLN","LBR","CKAP5","CENPE","CTCF","NEK2","G2E3","GAS2L3","CBX5","CENPA","MCM5","PCNA","TYMS","FEN1","MCM2","MCM4","RRM1","UNG","GINS2","MCM6","CDCA7","DTL","PRIM1","UHRF1","MLF1IP","HELLS","RFC2","RPA2","NASP","RAD51AP1","GMNN","WDR76","SLBP","CCNE2","UBR7","POLD3","MSH2","ATAD2","RAD51","RRM2","CDC45","CDC6","EXO1","TIPIN","DSCC1","BLM","CASP8AP2","USP1","CLSPN","POLA1","CHAF1B","BRIP1","E2F8"]]
#     if (isinstance(anndatapath, str)): cite = anndata.read_h5ad(anndatapath)
#     else: cite = anndatapath
#     if use_raw_slot_instead is None: # default behavior, check for the existance of the raw slot
#         use_raw_slot_instead = cite.raw is not None
#
#     split = splitAnnData(cite, field, entryfilter= cellfilter, getnames = True, use_raw_slot_instead= use_raw_slot_instead,min_cell_threshold=min_cell_threshold)
#     if genes_to_filter is not None:
#         for i in range(len(split["datalist"])):
#             split["datalist"][i] = split["datalist"][i][:, [g not in genes_to_filter for g in split["datalist"][i].var_names]]
#
#
#
#     dataset = GeneExpressionDataset()
#     if citeseqkey in cite.obsm.keys():
#         if citeseqkey is not "protein_expression":
#             for i in range(len(split["datalist"])):
#                 split["datalist"][i].obsm["protein_expression"] = split["datalist"][i].obsm[citeseqkey]
#         dataset.populate_from_datasets([AnnDatasetFromAnnData(ad=s,cell_measurements_col_mappings={"protein_expression":"protein_names"})   for s in split["datalist"] ])
#     else:
#         dataset.populate_from_datasets([AnnDatasetFromAnnData(ad=s)   for s in split["datalist"] ])
#
#     if nbgenes != 0: # nbgenes == 0 is a flag for the default behavior, which is to include all the genes
#         dataset.subsample_genes(nbgenes)
#     return{"dataset":dataset , "names" : split["ordered"]}
#
# Execution:
# [2020-11-16 10:13:24,388] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,450] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,451] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:24,460] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:24,462] INFO - scvi.dataset.dataset | Downsampled from 21 to 21 cells
# [2020-11-16 10:13:24,464] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,518] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,520] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:24,570] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:24,578] INFO - scvi.dataset.dataset | Downsampled from 197 to 197 cells
# [2020-11-16 10:13:24,582] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,608] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,610] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:24,620] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:24,622] INFO - scvi.dataset.dataset | Downsampled from 44 to 44 cells
# [2020-11-16 10:13:24,625] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,664] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,666] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:24,709] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:24,715] INFO - scvi.dataset.dataset | Downsampled from 167 to 167 cells
# [2020-11-16 10:13:24,719] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,750] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,751] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:24,789] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:24,794] INFO - scvi.dataset.dataset | Downsampled from 147 to 147 cells
# [2020-11-16 10:13:24,797] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,822] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,824] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:24,830] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:24,832] INFO - scvi.dataset.dataset | Downsampled from 26 to 26 cells
# [2020-11-16 10:13:24,835] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,858] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,860] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:24,862] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:24,865] INFO - scvi.dataset.dataset | Downsampled from 7 to 7 cells
# [2020-11-16 10:13:24,867] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:24,935] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:24,937] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,019] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,035] INFO - scvi.dataset.dataset | Downsampled from 329 to 329 cells
# [2020-11-16 10:13:25,039] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,065] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,067] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,069] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,071] INFO - scvi.dataset.dataset | Downsampled from 6 to 6 cells
# [2020-11-16 10:13:25,073] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,105] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,106] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,124] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,127] INFO - scvi.dataset.dataset | Downsampled from 70 to 70 cells
# [2020-11-16 10:13:25,130] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,157] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,159] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,166] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,168] INFO - scvi.dataset.dataset | Downsampled from 23 to 23 cells
# [2020-11-16 10:13:25,170] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,235] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,237] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,319] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,334] INFO - scvi.dataset.dataset | Downsampled from 308 to 308 cells
# [2020-11-16 10:13:25,338] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,366] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,368] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,375] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,377] INFO - scvi.dataset.dataset | Downsampled from 31 to 31 cells
# [2020-11-16 10:13:25,379] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,419] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,421] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,467] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,474] INFO - scvi.dataset.dataset | Downsampled from 178 to 178 cells
# [2020-11-16 10:13:25,477] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,508] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,510] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,547] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,552] INFO - scvi.dataset.dataset | Downsampled from 141 to 141 cells
# [2020-11-16 10:13:25,556] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,581] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,583] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,593] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,596] INFO - scvi.dataset.dataset | Downsampled from 42 to 42 cells
# [2020-11-16 10:13:25,598] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,628] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,630] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,645] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,648] INFO - scvi.dataset.dataset | Downsampled from 69 to 69 cells
# [2020-11-16 10:13:25,651] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:13:25,679] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:25,681] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:25,691] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:25,693] INFO - scvi.dataset.dataset | Downsampled from 42 to 42 cells
# [2020-11-16 10:13:25,695] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-16 10:13:25,695] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-16 10:13:26,065] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-16 10:13:26,092] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,100] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,101] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,172] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,205] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,207] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,239] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,249] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,251] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,312] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,336] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,338] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,393] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,414] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,416] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,443] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,451] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,452] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,475] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,480] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,482] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,586] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,636] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,638] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,661] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,666] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,667] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,704] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,717] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,719] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,745] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,752] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,754] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,857] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,902] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,904] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:26,931] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:26,939] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:26,941] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:27,003] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:27,028] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:27,030] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:27,086] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:27,108] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:27,110] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:27,142] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:27,152] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:27,153] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:27,189] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:27,203] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:27,204] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:27,235] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:13:27,244] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:27,246] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:13:27,645] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:13:27,647] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]

# %%
# run scvi
latent = lpy.runSCVI(das["dataset"], n_latent= 16, doinspect=True)
# Out:
# Run scvi
# def runSCVI(dataset, nbstep = 500, n_latent = 64, doinspect= False):
#     if doinspect is True: print("\033Run scvi\033\033"); print(inspect.getsource(runSCVI));print("\033Execution:\033")
#     vae = VAE(dataset.nb_genes, n_batch= dataset.n_batches, n_labels= dataset.n_labels, n_latent = n_latent)
#     trainer = UnsupervisedTrainer(vae, dataset, train_size=0.9, frequency=5, use_cuda=True)
#     trainer.train(n_epochs=nbstep)
#     full = trainer.create_posterior(trainer.model, dataset, indices=np.arange(len(dataset)))
#     return(full.sequential().get_latent()[0])
#
# Execution:
# [2020-11-16 10:13:38,788] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…

# %%
# store UMAP representation only for immune cells
adata = lpy.insertLatent(adata,latent, None, "X_umap_immune_curated", None, None, cellnames = das["names"], doinspect=True)
# Out:
# Compute Clusters and Reduces representations
# def insertLatent(adata, latent , latent_key= "latent", umap_key= "X_umap", tsne_key = "X_tsne", leiden_key = "leiden", rename_cluster_key= None,cellfilter = None, cellnames =None, leiden_resolution=1.0,doinspect=False):
#     if doinspect is True: print("\033Compute Clusters and Reduces representations\033\033"); print(inspect.getsource(insertLatent));print("\033Execution:\033")
#
#
#     if cellnames is None:
#         #order of full must match
#         assert latent.shape[0] == len(adata.obs_names),  "cell names need for be provided if size of latent mismatches adata"
#         map = range(len(adata.obs_names))
#         if latent_key is not None:
#             adata.obsm[latent_key] = latent
#     else:
#         print("defining permutation")
#         dalist = list(adata.obs_names)
#         tmap = {}
#         for i in range(len(adata.obs_names)):
#             tmap.update( {adata.obs_names[i] : i})
# # for i in range(len(adata.obs_names))}
#         map = [tmap[s] for s in cellnames]
#         if latent_key is not None:
#             print("Inserting Latent coords")
#             adata.obsm[latent_key] = np.zeros( (len(adata.obs_names), latent.shape[1]) )
#             for i in range(len(map)):
#                 adata.obsm[latent_key][map[i],:] = latent[i,:]
#
#     if umap_key is not None:
#         import umap.umap_ as umap
#         print("computing UMAP")
#         tumap = umap.UMAP(spread=2).fit_transform(latent)
#         adata.obsm[umap_key] = np.zeros( ( len(adata.obs_names), 2 ) )
#
#         print("Inserting Umap coords")
#         for i in range(len(map)):
#             adata.obsm[umap_key][map[i],:] = tumap[i,:]
#
#     if tsne_key is not None:
#         import scanpy as sc
#         print("computing Tsne")
#         adata_latent = sc.AnnData(latent)
#
#         sc.tl.tsne(adata_latent, use_rep='X', n_jobs=8)
#         adata.obsm[tsne_key] = np.zeros( ( len(adata.obs_names), 2 ) )
#
#         print("Inserting Tsne coords")
#         for i in range(len(map)):
#             adata.obsm[tsne_key][map[i],:] = adata_latent.obsm["X_tsne"][i,:]
#
#     if leiden_key is not None:
#         import scanpy as sc
#         adata_latent = sc.AnnData(latent)
#         print("Finding clusters")
#         sc.pp.neighbors(adata_latent, use_rep='X', n_neighbors=30, metric='minkowski')
#         sc.tl.leiden(adata_latent, resolution=leiden_resolution)
#         adata.obs[leiden_key] = "filtered"
#         #if rename_cluster_key is not None:
#         #    print("Renaming to do...")
#         #    for i
#         #else
#         #    ctnames = range(200)
#
#         print("Inserting Cluster Id")
#         for i in range(len(map)):
#             adata.obs[leiden_key][map[i]] = adata_latent.obs["leiden"][i]
#     return adata
#
# Execution:
# defining permutation
# computing UMAP
# Inserting Umap coords

# %%
das = lpy.scvi_prepare(adata, "SampleID", [x not in ["13","18","12", "filtered"] for x in  adata.obs["leidenres2_epithelial_subsample_raw"] ], nbgenes = 0, min_cell_threshold= 2)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "epithelial_curated", "X_umap_epithelial_curated", None, "leiden_epithelial_curated", cellnames = das["names"])
adata = lpy.insertLatent(adata,latent, None, None, None, "leidenres2_epithelial_curated", cellnames = das["names"], leiden_resolution=2)
# Out:
# [2020-11-16 10:16:22,990] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:23,027] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:23,029] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:23,045] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:23,047] INFO - scvi.dataset.dataset | Downsampled from 46 to 46 cells
# [2020-11-16 10:16:23,050] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:23,123] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:23,125] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:23,226] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:23,243] INFO - scvi.dataset.dataset | Downsampled from 349 to 349 cells
# [2020-11-16 10:16:23,247] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:23,399] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:23,401] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:23,678] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:23,724] INFO - scvi.dataset.dataset | Downsampled from 956 to 956 cells
# [2020-11-16 10:16:23,730] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:23,883] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:23,885] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:24,186] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:24,234] INFO - scvi.dataset.dataset | Downsampled from 995 to 995 cells
# [2020-11-16 10:16:24,240] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:24,273] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:24,275] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:24,312] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:24,317] INFO - scvi.dataset.dataset | Downsampled from 127 to 127 cells
# [2020-11-16 10:16:24,320] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:24,474] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:24,476] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:24,777] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:24,824] INFO - scvi.dataset.dataset | Downsampled from 990 to 990 cells
# [2020-11-16 10:16:24,831] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:24,982] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:24,984] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:25,304] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:25,352] INFO - scvi.dataset.dataset | Downsampled from 996 to 996 cells
# [2020-11-16 10:16:25,358] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:25,497] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:25,499] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:25,767] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:25,810] INFO - scvi.dataset.dataset | Downsampled from 874 to 874 cells
# [2020-11-16 10:16:25,816] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:25,964] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:25,966] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:26,246] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:26,292] INFO - scvi.dataset.dataset | Downsampled from 974 to 974 cells
# [2020-11-16 10:16:26,298] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:26,449] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:26,451] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:26,758] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:26,806] INFO - scvi.dataset.dataset | Downsampled from 997 to 997 cells
# [2020-11-16 10:16:26,812] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:26,941] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:26,943] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:27,214] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:27,252] INFO - scvi.dataset.dataset | Downsampled from 794 to 794 cells
# [2020-11-16 10:16:27,257] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:27,410] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:27,412] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:27,722] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:27,770] INFO - scvi.dataset.dataset | Downsampled from 999 to 999 cells
# [2020-11-16 10:16:27,776] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:27,842] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:27,844] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:27,926] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:27,942] INFO - scvi.dataset.dataset | Downsampled from 326 to 326 cells
# [2020-11-16 10:16:27,947] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:28,017] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:28,019] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:28,125] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:28,142] INFO - scvi.dataset.dataset | Downsampled from 350 to 350 cells
# [2020-11-16 10:16:28,147] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:28,180] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:28,182] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:28,206] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:28,209] INFO - scvi.dataset.dataset | Downsampled from 74 to 74 cells
# [2020-11-16 10:16:28,212] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:28,237] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:28,239] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:28,240] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:28,242] INFO - scvi.dataset.dataset | Downsampled from 2 to 2 cells
# [2020-11-16 10:16:28,244] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:28,378] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:28,380] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:28,605] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:28,645] INFO - scvi.dataset.dataset | Downsampled from 829 to 829 cells
# [2020-11-16 10:16:28,651] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 10:16:28,678] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:28,680] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:28,693] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:28,696] INFO - scvi.dataset.dataset | Downsampled from 50 to 50 cells
# [2020-11-16 10:16:28,697] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-16 10:16:28,698] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-16 10:16:29,071] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-16 10:16:29,109] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:29,120] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:29,122] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:29,250] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:29,299] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:29,301] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:29,608] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:29,737] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:29,739] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:30,061] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:30,193] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:30,195] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:30,249] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:30,270] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:30,272] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:30,593] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:30,724] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:30,726] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:31,058] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:31,189] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:31,191] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:31,474] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:31,592] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:31,594] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:31,900] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:32,034] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:32,036] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:32,361] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:32,490] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:32,492] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:32,772] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:32,881] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:32,883] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:33,210] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:33,338] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:33,340] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:33,445] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:33,494] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:33,496] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:33,624] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:33,676] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:33,678] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:33,723] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:33,737] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:33,739] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:33,761] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:33,767] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:33,768] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:34,017] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:34,128] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:34,130] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:34,165] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 10:16:34,176] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:34,178] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:36,397] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 10:16:36,399] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 10:16:38,082] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id
# defining permutation
# Finding clusters
# Inserting Cluster Id

# %%
das = lpy.scvi_prepare(adata, "SampleID", [x not in ["1","7","9","11", "10", "filtered"] for x in  adata.obs["leiden_stromal_subsample_raw"] ], nbgenes = 0, min_cell_threshold= 2)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "stromal_curated", "X_umap_stromal_curated", None, "leiden_stromal_curated", cellnames = das["names"])
adata = lpy.insertLatent(adata,latent, None, None, None, "leidenres2_stromal_curated", cellnames = das["names"], leiden_resolution=2)
# Out:
# [2020-11-16 13:13:42,886] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:43,123] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:43,125] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:43,715] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:43,780] INFO - scvi.dataset.dataset | Downsampled from 908 to 908 cells
# [2020-11-16 13:13:43,791] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:43,965] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:43,967] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:44,297] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:44,349] INFO - scvi.dataset.dataset | Downsampled from 775 to 775 cells
# [2020-11-16 13:13:44,359] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:44,416] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:44,417] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:44,507] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:44,518] INFO - scvi.dataset.dataset | Downsampled from 210 to 210 cells
# [2020-11-16 13:13:44,523] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:44,689] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:44,691] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:44,994] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:45,042] INFO - scvi.dataset.dataset | Downsampled from 705 to 705 cells
# [2020-11-16 13:13:45,052] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:45,150] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:45,153] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:45,303] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:45,327] INFO - scvi.dataset.dataset | Downsampled from 333 to 333 cells
# [2020-11-16 13:13:45,334] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:45,510] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:45,511] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:45,843] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:45,894] INFO - scvi.dataset.dataset | Downsampled from 776 to 776 cells
# [2020-11-16 13:13:45,904] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:46,089] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:46,091] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:46,452] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:46,511] INFO - scvi.dataset.dataset | Downsampled from 850 to 850 cells
# [2020-11-16 13:13:46,521] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:46,625] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:46,626] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:46,793] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:46,819] INFO - scvi.dataset.dataset | Downsampled from 367 to 367 cells
# [2020-11-16 13:13:46,827] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:46,869] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:46,870] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:46,881] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:46,884] INFO - scvi.dataset.dataset | Downsampled from 18 to 18 cells
# [2020-11-16 13:13:46,887] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:47,030] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:47,031] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:47,283] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:47,323] INFO - scvi.dataset.dataset | Downsampled from 567 to 567 cells
# [2020-11-16 13:13:47,331] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:47,492] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:47,493] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:47,795] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:47,840] INFO - scvi.dataset.dataset | Downsampled from 693 to 693 cells
# [2020-11-16 13:13:47,850] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:47,894] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:47,895] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:47,923] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:47,927] INFO - scvi.dataset.dataset | Downsampled from 59 to 59 cells
# [2020-11-16 13:13:47,932] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:48,151] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:48,152] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:48,582] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:48,647] INFO - scvi.dataset.dataset | Downsampled from 974 to 974 cells
# [2020-11-16 13:13:48,658] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:48,701] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:48,702] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:48,731] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:48,735] INFO - scvi.dataset.dataset | Downsampled from 64 to 64 cells
# [2020-11-16 13:13:48,740] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:48,934] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:48,936] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:49,308] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:49,366] INFO - scvi.dataset.dataset | Downsampled from 849 to 849 cells
# [2020-11-16 13:13:49,376] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:49,420] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:49,422] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:49,441] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:49,445] INFO - scvi.dataset.dataset | Downsampled from 48 to 48 cells
# [2020-11-16 13:13:49,449] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:49,639] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:49,640] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:49,996] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:50,052] INFO - scvi.dataset.dataset | Downsampled from 820 to 820 cells
# [2020-11-16 13:13:50,063] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:50,257] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:50,258] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:50,638] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:50,693] INFO - scvi.dataset.dataset | Downsampled from 851 to 851 cells
# [2020-11-16 13:13:50,704] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:50,857] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:50,859] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:51,160] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:51,204] INFO - scvi.dataset.dataset | Downsampled from 644 to 644 cells
# [2020-11-16 13:13:51,214] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:51,265] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:51,268] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:51,320] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:51,327] INFO - scvi.dataset.dataset | Downsampled from 125 to 125 cells
# [2020-11-16 13:13:51,332] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-16 13:13:51,392] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:51,393] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:51,470] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:51,481] INFO - scvi.dataset.dataset | Downsampled from 197 to 197 cells
# [2020-11-16 13:13:51,485] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-16 13:13:51,487] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-16 13:13:52,167] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-16 13:13:52,633] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:52,799] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:52,800] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:53,191] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:53,336] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:53,337] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:53,462] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:53,502] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:53,503] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:53,861] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:53,992] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:53,993] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:54,186] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:54,257] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:54,258] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:54,660] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:54,798] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:54,800] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:55,227] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:55,387] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:55,388] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:55,599] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:55,676] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:55,677] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:55,723] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:55,733] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:55,735] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:56,028] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:56,131] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:56,132] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:56,488] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:56,615] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:56,616] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:56,681] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:56,699] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:56,700] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:57,180] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:57,362] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:57,363] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:57,432] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:57,450] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:57,453] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:57,884] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:58,044] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:58,045] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:58,104] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:58,119] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:58,122] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:58,530] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:58,681] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:58,682] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:59,114] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:59,278] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:59,280] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:59,632] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:59,750] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:59,754] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:59,838] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:13:59,864] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:13:59,865] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:13:59,981] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-16 13:14:00,026] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:14:00,029] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:14:03,044] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-16 13:14:03,046] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-16 13:14:13,977] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id
# defining permutation
# Finding clusters
# Inserting Cluster Id

# %%
adata.write_h5ad("N5-integrated_donors.h5ad")
# Out:
# ... storing 'leiden_stromal_curated' as categorical
# ... storing 'leidenres2_stromal_curated' as categorical
