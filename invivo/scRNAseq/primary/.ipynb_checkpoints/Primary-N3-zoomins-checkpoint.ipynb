# %%
# Integration of biopsies and organ donors from 2 studies
import anndata, numpy as np, pandas as pd, imp, lpy, scanpy as sc
sc.logging.print_versions()
# Out:
# scanpy==1.5.1 anndata==0.7.4 umap==0.4.6 numpy==1.19.1 scipy==1.5.2 pandas==1.0.5 scikit-learn==0.23.2 statsmodels==0.11.1 python-igraph==0.8.2 louvain==0.6.1 leidenalg==0.8.1

# %%
# Set some constants
adata = anndata.read_h5ad("N2-integrated_donors.h5ad")

# %%
# Integrate the Endothelial cell fraction specifically
# Use sample for batch correction, and integrate all genes
das = lpy.scvi_prepare(adata, "SampleID", adata.obs["broad_celltypes"] == "Endothelial", nbgenes = 0, doinspect=True)
# Out:
# Prepare Data for Scvi/TotalVi
# def scvi_prepare(anndatapath, field, cellfilter = None, nbgenes = 5000, genes_to_filter= None, use_ccfilter_prefix=None, citeseqkey = "protein_expression", use_raw_slot_instead =None, min_cell_threshold= 0, doinspect=False):
#     if doinspect is True: print("\033Prepare Data for Scvi/TotalVi\033\033"); print(inspect.getsource(scvi_prepare));print("\033Execution:\033")
#     if use_ccfilter_prefix is not None :
#         genes_to_filter = [use_ccfilter_prefix + x for x in ["HMGB2","CDK1","NUSAP1","UBE2C","BIRC5","TPX2","TOP2A","NDC80","CKS2","NUF2","CKS1B","MKI67","TMPO","CENPF","TACC3","FAM64A","SMC4","CCNB2","CKAP2L","CKAP2","AURKB","BUB1","KIF11","ANP32E","TUBB4B","GTSE1","KIF20B","HJURP","CDCA3","HN1","CDC20","TTK","CDC25C","KIF2C","RANGAP1","NCAPD2","DLGAP5","CDCA2","CDCA8","ECT2","KIF23","HMMR","AURKA","PSRC1","ANLN","LBR","CKAP5","CENPE","CTCF","NEK2","G2E3","GAS2L3","CBX5","CENPA","MCM5","PCNA","TYMS","FEN1","MCM2","MCM4","RRM1","UNG","GINS2","MCM6","CDCA7","DTL","PRIM1","UHRF1","MLF1IP","HELLS","RFC2","RPA2","NASP","RAD51AP1","GMNN","WDR76","SLBP","CCNE2","UBR7","POLD3","MSH2","ATAD2","RAD51","RRM2","CDC45","CDC6","EXO1","TIPIN","DSCC1","BLM","CASP8AP2","USP1","CLSPN","POLA1","CHAF1B","BRIP1","E2F8"]]
#     if (isinstance(anndatapath, str)): cite = anndata.read_h5ad(anndatapath)
#     else: cite = anndatapath
#     if use_raw_slot_instead is None: # default behavior, check for the existance of the raw slot
#         use_raw_slot_instead = cite.raw is not None
#
#     split = splitAnnData(cite, field, entryfilter= cellfilter, getnames = True, use_raw_slot_instead= use_raw_slot_instead,min_cell_threshold=min_cell_threshold)
#     if genes_to_filter is not None:
#         for i in range(len(split["datalist"])):
#             split["datalist"][i] = split["datalist"][i][:, [g not in genes_to_filter for g in split["datalist"][i].var_names]]
#
#
#
#     dataset = GeneExpressionDataset()
#     if citeseqkey in cite.obsm.keys():
#         if citeseqkey is not "protein_expression":
#             for i in range(len(split["datalist"])):
#                 split["datalist"][i].obsm["protein_expression"] = split["datalist"][i].obsm[citeseqkey]
#         dataset.populate_from_datasets([AnnDatasetFromAnnData(ad=s,cell_measurements_col_mappings={"protein_expression":"protein_names"})   for s in split["datalist"] ])
#     else:
#         dataset.populate_from_datasets([AnnDatasetFromAnnData(ad=s)   for s in split["datalist"] ])
#
#     if nbgenes != 0: # nbgenes == 0 is a flag for the default behavior, which is to include all the genes
#         dataset.subsample_genes(nbgenes)
#     return{"dataset":dataset , "names" : split["ordered"]}
#
# Execution:
# [2020-11-04 16:39:37,437] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:37,503] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:37,506] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:37,508] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:37,511] INFO - scvi.dataset.dataset | Downsampled from 4 to 4 cells
# [2020-11-04 16:39:37,513] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:37,569] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:37,571] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:37,609] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:37,612] INFO - scvi.dataset.dataset | Downsampled from 90 to 90 cells
# [2020-11-04 16:39:37,618] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:37,983] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:37,985] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:38,621] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:38,745] INFO - scvi.dataset.dataset | Downsampled from 2424 to 2424 cells
# [2020-11-04 16:39:38,760] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:38,836] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:38,838] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:38,955] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:38,975] INFO - scvi.dataset.dataset | Downsampled from 371 to 371 cells
# [2020-11-04 16:39:38,980] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,010] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,012] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,029] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,031] INFO - scvi.dataset.dataset | Downsampled from 58 to 58 cells
# [2020-11-04 16:39:39,034] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,090] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,092] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,154] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,163] INFO - scvi.dataset.dataset | Downsampled from 222 to 222 cells
# [2020-11-04 16:39:39,167] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,194] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,196] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,216] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,220] INFO - scvi.dataset.dataset | Downsampled from 78 to 78 cells
# [2020-11-04 16:39:39,222] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,277] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,279] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,341] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,350] INFO - scvi.dataset.dataset | Downsampled from 225 to 225 cells
# [2020-11-04 16:39:39,355] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,378] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,379] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,382] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,384] INFO - scvi.dataset.dataset | Downsampled from 8 to 8 cells
# [2020-11-04 16:39:39,386] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,412] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,414] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,433] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,436] INFO - scvi.dataset.dataset | Downsampled from 64 to 64 cells
# [2020-11-04 16:39:39,438] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,501] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,503] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,588] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,600] INFO - scvi.dataset.dataset | Downsampled from 283 to 283 cells
# [2020-11-04 16:39:39,605] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:39,633] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:39,635] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:39,667] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:39,671] INFO - scvi.dataset.dataset | Downsampled from 112 to 112 cells
# [2020-11-04 16:39:39,674] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:40,011] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:40,013] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:40,656] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:40,773] INFO - scvi.dataset.dataset | Downsampled from 2304 to 2304 cells
# [2020-11-04 16:39:40,788] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:40,895] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:40,897] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,062] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,094] INFO - scvi.dataset.dataset | Downsampled from 596 to 596 cells
# [2020-11-04 16:39:41,101] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:41,129] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:41,131] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,143] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,145] INFO - scvi.dataset.dataset | Downsampled from 44 to 44 cells
# [2020-11-04 16:39:41,148] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:41,173] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:41,175] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,177] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,179] INFO - scvi.dataset.dataset | Downsampled from 5 to 5 cells
# [2020-11-04 16:39:41,181] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:41,214] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:41,216] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,243] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,247] INFO - scvi.dataset.dataset | Downsampled from 95 to 95 cells
# [2020-11-04 16:39:41,250] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:41,272] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:41,274] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,277] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,280] INFO - scvi.dataset.dataset | Downsampled from 9 to 9 cells
# [2020-11-04 16:39:41,282] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:41,378] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:41,379] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,523] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,550] INFO - scvi.dataset.dataset | Downsampled from 534 to 534 cells
# [2020-11-04 16:39:41,556] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:41,582] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:41,584] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,593] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,595] INFO - scvi.dataset.dataset | Downsampled from 31 to 31 cells
# [2020-11-04 16:39:41,597] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 16:39:41,623] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:41,625] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:41,632] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:41,634] INFO - scvi.dataset.dataset | Downsampled from 20 to 20 cells
# [2020-11-04 16:39:41,635] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-04 16:39:41,636] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-04 16:39:42,073] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-04 16:39:42,096] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:42,102] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:42,104] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:42,152] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:42,169] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:42,171] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:42,871] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,192] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,194] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,336] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,390] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,392] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,430] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,443] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,445] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,526] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,564] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,565] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,607] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,629] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,631] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,717] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,755] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,757] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,781] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,787] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,788] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,827] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,840] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,842] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:43,946] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:43,984] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:43,986] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:44,037] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:44,056] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:44,058] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:44,737] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:45,298] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:45,300] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:45,488] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:45,571] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:45,573] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:45,610] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:45,621] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:45,622] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:45,646] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:45,652] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:45,653] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:45,702] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:45,720] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:45,722] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:45,747] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:45,753] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:45,754] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:45,923] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:46,000] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:46,002] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:46,034] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:46,043] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:46,044] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:46,073] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 16:39:46,080] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:46,082] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 16:39:48,080] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 16:39:48,082] INFO - scvi.dataset.dataset | Remapping labels to [0,N]

# %%
# run scvi
latent = lpy.runSCVI(das["dataset"], n_latent= 16, doinspect=True)
# Out:
# Run scvi
# def runSCVI(dataset, nbstep = 500, n_latent = 64, doinspect= False):
#     if doinspect is True: print("\033Run scvi\033\033"); print(inspect.getsource(runSCVI));print("\033Execution:\033")
#     vae = VAE(dataset.nb_genes, n_batch= dataset.n_batches, n_labels= dataset.n_labels, n_latent = n_latent)
#     trainer = UnsupervisedTrainer(vae, dataset, train_size=0.9, frequency=5, use_cuda=True)
#     trainer.train(n_epochs=nbstep)
#     full = trainer.create_posterior(trainer.model, dataset, indices=np.arange(len(dataset)))
#     return(full.sequential().get_latent()[0])
#
# Execution:
# [2020-11-04 16:40:01,437] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…

# %%
# store latent variable back in th object, and produce UMAP coordinates and leiden clusters 
adata = lpy.insertLatent(adata,latent, "endothelial", "X_umap_endothelial", None, "leiden_endothelial_raw", cellnames = das["names"], doinspect=True)
# Out:
# Compute Clusters and Reduces representations
# def insertLatent(adata, latent , latent_key= "latent", umap_key= "X_umap", tsne_key = "X_tsne", leiden_key = "leiden", rename_cluster_key= None,cellfilter = None, cellnames =None, leiden_resolution=1.0,doinspect=False):
#     if doinspect is True: print("\033Compute Clusters and Reduces representations\033\033"); print(inspect.getsource(insertLatent));print("\033Execution:\033")
#
#
#     if cellnames is None:
#         #order of full must match
#         assert latent.shape[0] == len(adata.obs_names),  "cell names need for be provided if size of latent mismatches adata"
#         map = range(len(adata.obs_names))
#         if latent_key is not None:
#             adata.obsm[latent_key] = latent
#     else:
#         print("defining permutation")
#         dalist = list(adata.obs_names)
#         tmap = {}
#         for i in range(len(adata.obs_names)):
#             tmap.update( {adata.obs_names[i] : i})
# # for i in range(len(adata.obs_names))}
#         map = [tmap[s] for s in cellnames]
#         if latent_key is not None:
#             print("Inserting Latent coords")
#             adata.obsm[latent_key] = np.zeros( (len(adata.obs_names), latent.shape[1]) )
#             for i in range(len(map)):
#                 adata.obsm[latent_key][map[i],:] = latent[i,:]
#
#     if umap_key is not None:
#         import umap.umap_ as umap
#         print("computing UMAP")
#         tumap = umap.UMAP(spread=2).fit_transform(latent)
#         adata.obsm[umap_key] = np.zeros( ( len(adata.obs_names), 2 ) )
#
#         print("Inserting Umap coords")
#         for i in range(len(map)):
#             adata.obsm[umap_key][map[i],:] = tumap[i,:]
#
#     if tsne_key is not None:
#         import scanpy as sc
#         print("computing Tsne")
#         adata_latent = sc.AnnData(latent)
#
#         sc.tl.tsne(adata_latent, use_rep='X', n_jobs=8)
#         adata.obsm[tsne_key] = np.zeros( ( len(adata.obs_names), 2 ) )
#
#         print("Inserting Tsne coords")
#         for i in range(len(map)):
#             adata.obsm[tsne_key][map[i],:] = adata_latent.obsm["X_tsne"][i,:]
#
#     if leiden_key is not None:
#         import scanpy as sc
#         adata_latent = sc.AnnData(latent)
#         print("Finding clusters")
#         sc.pp.neighbors(adata_latent, use_rep='X', n_neighbors=30, metric='minkowski')
#         sc.tl.leiden(adata_latent, resolution=leiden_resolution)
#         adata.obs[leiden_key] = "filtered"
#         #if rename_cluster_key is not None:
#         #    print("Renaming to do...")
#         #    for i
#         #else
#         #    ctnames = range(200)
#
#         print("Inserting Cluster Id")
#         for i in range(len(map)):
#             adata.obs[leiden_key][map[i]] = adata_latent.obs["leiden"][i]
#     return adata
#
# Execution:
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id

# %%
# Integrate the Immune cells fraction specifically
# uses the same method used in the last 3 cells with identical parameters
das = lpy.scvi_prepare(adata, "SampleID", adata.obs["broad_celltypes"] == "Immune", nbgenes = 0)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "immune", "X_umap_immune", None, "leiden_immune_raw", cellnames = das["names"])
# Out:
# [2020-11-04 17:34:47,623] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:47,703] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:47,706] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:47,739] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:47,741] INFO - scvi.dataset.dataset | Downsampled from 18 to 18 cells
# [2020-11-04 17:34:47,745] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:47,787] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:47,788] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:47,819] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:47,824] INFO - scvi.dataset.dataset | Downsampled from 82 to 82 cells
# [2020-11-04 17:34:47,827] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:47,869] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:47,870] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:47,907] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:47,913] INFO - scvi.dataset.dataset | Downsampled from 109 to 109 cells
# [2020-11-04 17:34:47,917] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:47,976] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:47,979] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,032] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,039] INFO - scvi.dataset.dataset | Downsampled from 184 to 184 cells
# [2020-11-04 17:34:48,042] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,068] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,069] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,077] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,079] INFO - scvi.dataset.dataset | Downsampled from 23 to 23 cells
# [2020-11-04 17:34:48,081] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,129] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,130] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,196] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,206] INFO - scvi.dataset.dataset | Downsampled from 262 to 262 cells
# [2020-11-04 17:34:48,210] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,247] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,249] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,302] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,311] INFO - scvi.dataset.dataset | Downsampled from 222 to 222 cells
# [2020-11-04 17:34:48,314] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,352] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,354] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,413] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,422] INFO - scvi.dataset.dataset | Downsampled from 233 to 233 cells
# [2020-11-04 17:34:48,425] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,450] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,451] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,455] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,457] INFO - scvi.dataset.dataset | Downsampled from 8 to 8 cells
# [2020-11-04 17:34:48,458] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,483] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,484] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,492] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,494] INFO - scvi.dataset.dataset | Downsampled from 31 to 31 cells
# [2020-11-04 17:34:48,497] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,524] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,526] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,550] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,554] INFO - scvi.dataset.dataset | Downsampled from 100 to 100 cells
# [2020-11-04 17:34:48,557] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,588] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,590] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,622] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,626] INFO - scvi.dataset.dataset | Downsampled from 125 to 125 cells
# [2020-11-04 17:34:48,629] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,652] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,654] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,657] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,658] INFO - scvi.dataset.dataset | Downsampled from 5 to 5 cells
# [2020-11-04 17:34:48,661] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,687] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,689] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,701] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,704] INFO - scvi.dataset.dataset | Downsampled from 54 to 54 cells
# [2020-11-04 17:34:48,706] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,782] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,784] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:48,884] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:48,902] INFO - scvi.dataset.dataset | Downsampled from 371 to 371 cells
# [2020-11-04 17:34:48,907] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:48,983] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:48,985] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:49,084] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:49,103] INFO - scvi.dataset.dataset | Downsampled from 400 to 400 cells
# [2020-11-04 17:34:49,109] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:49,138] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:49,140] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:49,151] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:49,154] INFO - scvi.dataset.dataset | Downsampled from 47 to 47 cells
# [2020-11-04 17:34:49,156] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:49,183] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:49,185] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:49,191] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:49,193] INFO - scvi.dataset.dataset | Downsampled from 21 to 21 cells
# [2020-11-04 17:34:49,195] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:49,286] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:49,288] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:49,414] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:49,438] INFO - scvi.dataset.dataset | Downsampled from 507 to 507 cells
# [2020-11-04 17:34:49,444] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:49,488] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:49,490] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:49,550] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:49,560] INFO - scvi.dataset.dataset | Downsampled from 224 to 224 cells
# [2020-11-04 17:34:49,563] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:34:49,589] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:49,591] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:49,603] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:49,605] INFO - scvi.dataset.dataset | Downsampled from 46 to 46 cells
# [2020-11-04 17:34:49,607] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-04 17:34:49,608] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-04 17:34:50,041] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-04 17:34:50,068] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,075] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,077] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,119] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,134] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,136] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,181] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,199] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,200] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,272] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,300] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,302] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,330] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,337] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,339] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,427] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,463] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,464] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,538] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,572] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,574] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,650] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,683] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,684] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,708] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,714] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,716] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,744] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,753] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,754] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,798] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,814] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,816] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,867] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,885] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,887] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,910] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,915] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,916] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:50,949] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:50,961] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:50,962] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:51,079] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:51,132] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:51,133] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:51,258] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:51,315] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:51,316] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:51,350] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:51,360] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:51,362] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:51,388] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:51,395] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:51,397] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:51,548] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:51,614] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:51,616] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:51,690] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:51,731] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:51,733] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:51,766] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:34:51,776] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:51,778] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:54,088] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:34:54,090] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:34:54,603] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id

# %%
# in addition find clusters with leiden resolution (for the immune population
adata = lpy.insertLatent(adata,latent, None, None, None, "leidenres3_immune_raw", cellnames = das["names"], leiden_resolution=3)
# Out:
# defining permutation
# Finding clusters
# Inserting Cluster Id

# %%
# Integrate the Stromal cells cell fraction specifically
# uses the same method as before with identical parameters
das = lpy.scvi_prepare(adata, "SampleID", adata.obs["broad_celltypes"] == "Stromal", nbgenes = 0)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "stromal", "X_umap_stromal", None, "leiden_stromal_raw", cellnames = das["names"])
# Out:
# ... storing 'leiden_immune_raw' as categorical
# ... storing 'leidenres3_immune_raw' as categorical
# [2020-11-04 17:39:51,903] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:51,942] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:51,944] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:51,966] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:39:51,969] INFO - scvi.dataset.dataset | Downsampled from 82 to 82 cells
# [2020-11-04 17:39:51,972] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:52,164] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:52,166] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:52,539] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:39:52,599] INFO - scvi.dataset.dataset | Downsampled from 1277 to 1277 cells
# [2020-11-04 17:39:52,609] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:52,838] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:52,840] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:53,225] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:39:53,299] INFO - scvi.dataset.dataset | Downsampled from 1581 to 1581 cells
# [2020-11-04 17:39:53,311] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:53,590] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:53,592] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:54,161] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:39:54,253] INFO - scvi.dataset.dataset | Downsampled from 1953 to 1953 cells
# [2020-11-04 17:39:54,266] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:54,387] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:54,389] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:54,596] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:39:54,632] INFO - scvi.dataset.dataset | Downsampled from 736 to 736 cells
# [2020-11-04 17:39:54,640] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:55,269] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:55,271] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:56,609] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:39:56,833] INFO - scvi.dataset.dataset | Downsampled from 4695 to 4695 cells
# [2020-11-04 17:39:56,859] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:57,090] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:57,092] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:57,529] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:39:57,604] INFO - scvi.dataset.dataset | Downsampled from 1586 to 1586 cells
# [2020-11-04 17:39:57,615] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:39:58,282] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:39:58,284] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:39:59,801] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:00,139] INFO - scvi.dataset.dataset | Downsampled from 4705 to 4705 cells
# [2020-11-04 17:40:00,166] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:00,199] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:00,201] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:00,224] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:00,227] INFO - scvi.dataset.dataset | Downsampled from 79 to 79 cells
# [2020-11-04 17:40:00,230] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:00,709] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:00,711] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:01,729] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:01,951] INFO - scvi.dataset.dataset | Downsampled from 2948 to 2948 cells
# [2020-11-04 17:40:01,969] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:02,164] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:02,166] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:02,531] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:02,612] INFO - scvi.dataset.dataset | Downsampled from 1099 to 1099 cells
# [2020-11-04 17:40:02,621] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:03,280] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:03,282] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:04,676] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:04,994] INFO - scvi.dataset.dataset | Downsampled from 4106 to 4106 cells
# [2020-11-04 17:40:05,018] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:05,091] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:05,093] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:05,190] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:05,212] INFO - scvi.dataset.dataset | Downsampled from 312 to 312 cells
# [2020-11-04 17:40:05,217] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:05,295] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:05,297] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:05,399] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:05,424] INFO - scvi.dataset.dataset | Downsampled from 344 to 344 cells
# [2020-11-04 17:40:05,429] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:06,019] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:06,021] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:07,281] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:07,555] INFO - scvi.dataset.dataset | Downsampled from 3645 to 3645 cells
# [2020-11-04 17:40:07,578] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:07,607] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:07,609] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:07,616] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:07,618] INFO - scvi.dataset.dataset | Downsampled from 24 to 24 cells
# [2020-11-04 17:40:07,620] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:07,869] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:07,871] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:08,365] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:08,470] INFO - scvi.dataset.dataset | Downsampled from 1425 to 1425 cells
# [2020-11-04 17:40:08,481] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:08,706] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:08,708] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:09,187] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:09,282] INFO - scvi.dataset.dataset | Downsampled from 1302 to 1302 cells
# [2020-11-04 17:40:09,292] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:09,946] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:09,948] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:11,214] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:11,521] INFO - scvi.dataset.dataset | Downsampled from 4058 to 4058 cells
# [2020-11-04 17:40:11,544] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:11,632] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:11,634] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:11,768] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:11,797] INFO - scvi.dataset.dataset | Downsampled from 399 to 399 cells
# [2020-11-04 17:40:11,802] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 17:40:11,947] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:11,949] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:12,207] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:12,263] INFO - scvi.dataset.dataset | Downsampled from 755 to 755 cells
# [2020-11-04 17:40:12,269] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-04 17:40:12,271] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-04 17:40:12,707] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-04 17:40:12,752] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:12,768] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:12,770] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:13,232] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:13,422] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:13,424] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:13,919] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:14,128] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:14,130] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:14,813] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:15,072] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:15,074] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:15,312] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:15,424] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:15,426] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:17,008] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:17,632] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:17,634] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:18,127] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:18,340] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:18,342] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:19,868] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:20,440] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:20,442] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:20,484] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:20,500] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:20,501] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:21,469] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:21,868] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:21,870] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:22,236] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:22,389] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:22,391] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:23,883] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:24,579] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:24,581] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:24,710] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:24,768] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:24,770] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:24,904] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:24,970] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:24,972] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:26,346] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:26,960] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:26,962] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:26,994] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:27,002] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:27,004] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:27,558] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:27,798] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:27,800] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:28,323] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:28,544] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:28,546] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:29,968] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:30,674] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:30,676] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:30,843] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:30,915] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:30,917] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:31,214] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 17:40:31,347] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:31,349] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:45,623] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 17:40:46,437] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 17:40:58,215] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id

# %%
# Integrate the Supporting cells fraction specifically
# uses the same method as before with identical parameters
das = lpy.scvi_prepare(adata, "SampleID", adata.obs["broad_celltypes"] == "Supporting", nbgenes = 0,min_cell_threshold=2)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "supporting", "X_umap_supporting", None, "leiden_supporting_raw", cellnames = das["names"])
# Out:
# [2020-11-04 21:25:05,196] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:05,786] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:05,788] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:06,851] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:07,026] INFO - scvi.dataset.dataset | Downsampled from 3713 to 3713 cells
# [2020-11-04 21:25:07,041] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:07,085] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:07,086] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:07,126] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:07,132] INFO - scvi.dataset.dataset | Downsampled from 156 to 156 cells
# [2020-11-04 21:25:07,135] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:07,162] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:07,163] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:07,171] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:07,173] INFO - scvi.dataset.dataset | Downsampled from 22 to 22 cells
# [2020-11-04 21:25:07,176] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:07,207] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:07,209] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:07,239] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:07,244] INFO - scvi.dataset.dataset | Downsampled from 111 to 111 cells
# [2020-11-04 21:25:07,247] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:07,273] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:07,275] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:07,290] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:07,293] INFO - scvi.dataset.dataset | Downsampled from 60 to 60 cells
# [2020-11-04 21:25:07,296] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:07,324] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:07,326] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:07,334] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:07,336] INFO - scvi.dataset.dataset | Downsampled from 23 to 23 cells
# [2020-11-04 21:25:07,338] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:07,776] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:07,778] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:08,598] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:08,752] INFO - scvi.dataset.dataset | Downsampled from 3268 to 3268 cells
# [2020-11-04 21:25:08,765] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:08,791] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:08,793] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:08,795] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:08,797] INFO - scvi.dataset.dataset | Downsampled from 6 to 6 cells
# [2020-11-04 21:25:08,799] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:08,833] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:08,835] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:08,875] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:08,881] INFO - scvi.dataset.dataset | Downsampled from 150 to 150 cells
# [2020-11-04 21:25:08,884] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:08,908] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:08,910] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:08,913] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:08,915] INFO - scvi.dataset.dataset | Downsampled from 9 to 9 cells
# [2020-11-04 21:25:08,918] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:08,981] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:08,983] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,068] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,084] INFO - scvi.dataset.dataset | Downsampled from 319 to 319 cells
# [2020-11-04 21:25:09,088] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:09,122] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:09,124] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,167] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,173] INFO - scvi.dataset.dataset | Downsampled from 162 to 162 cells
# [2020-11-04 21:25:09,176] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:09,239] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:09,241] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,330] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,345] INFO - scvi.dataset.dataset | Downsampled from 307 to 307 cells
# [2020-11-04 21:25:09,349] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:09,375] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:09,377] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,387] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,389] INFO - scvi.dataset.dataset | Downsampled from 35 to 35 cells
# [2020-11-04 21:25:09,392] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:09,462] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:09,464] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,561] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,578] INFO - scvi.dataset.dataset | Downsampled from 359 to 359 cells
# [2020-11-04 21:25:09,583] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:09,621] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:09,622] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,668] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,675] INFO - scvi.dataset.dataset | Downsampled from 171 to 171 cells
# [2020-11-04 21:25:09,678] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:09,702] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:09,704] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,711] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,714] INFO - scvi.dataset.dataset | Downsampled from 24 to 24 cells
# [2020-11-04 21:25:09,716] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:09,757] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:09,758] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:09,813] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:09,821] INFO - scvi.dataset.dataset | Downsampled from 210 to 210 cells
# [2020-11-04 21:25:09,825] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:10,790] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:10,792] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:12,617] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:12,971] INFO - scvi.dataset.dataset | Downsampled from 7484 to 7484 cells
# [2020-11-04 21:25:12,997] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:25:13,022] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:13,024] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:13,034] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:13,036] INFO - scvi.dataset.dataset | Downsampled from 32 to 32 cells
# [2020-11-04 21:25:13,038] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-04 21:25:13,038] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-04 21:25:13,433] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-04 21:25:14,474] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:14,932] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:14,934] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:14,995] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:15,018] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:15,020] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:15,050] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:15,057] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:15,059] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:15,110] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:15,129] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:15,131] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:15,169] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:15,181] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:15,183] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:15,212] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:15,219] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:15,221] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:16,112] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:16,530] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:16,532] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:16,558] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:16,563] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:16,564] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:16,623] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:16,648] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:16,650] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:16,676] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:16,681] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:16,683] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:16,792] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:16,836] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:16,838] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:16,902] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:16,926] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:16,928] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:17,040] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:17,083] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:17,085] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:17,118] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:17,127] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:17,129] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:17,249] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:17,299] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:17,301] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:17,366] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:17,392] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:17,394] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:17,423] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:17,431] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:17,432] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:17,511] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:17,541] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:17,543] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:19,500] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:20,443] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:20,445] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:20,479] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:25:20,487] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:20,489] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:23,742] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:25:23,744] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:25:33,014] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id

# %%
# Integrate the Epithelial cells fraction specifically
# uses the same method as before with identical parameters
das = lpy.scvi_prepare(adata, "SampleID", adata.obs["broad_celltypes"] == "Epithelial", nbgenes = 0, min_cell_threshold= 2)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "epithelial", "X_umap_epithelial", None, "leiden_epithelial_raw", cellnames = das["names"])
# Out:
# [2020-11-04 21:52:35,768] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:35,770] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:37,763] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:37,874] INFO - scvi.dataset.dataset | Downsampled from 15483 to 15483 cells
# [2020-11-04 21:52:37,881] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:37,921] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:37,923] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:37,944] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:37,948] INFO - scvi.dataset.dataset | Downsampled from 50 to 50 cells
# [2020-11-04 21:52:37,951] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:38,090] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:38,091] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:38,364] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:38,402] INFO - scvi.dataset.dataset | Downsampled from 802 to 802 cells
# [2020-11-04 21:52:38,408] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:38,772] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:38,774] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:39,559] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:39,685] INFO - scvi.dataset.dataset | Downsampled from 2679 to 2679 cells
# [2020-11-04 21:52:39,697] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:39,722] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:39,724] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:39,725] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:39,727] INFO - scvi.dataset.dataset | Downsampled from 3 to 3 cells
# [2020-11-04 21:52:39,729] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:39,759] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:39,761] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:39,778] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:39,781] INFO - scvi.dataset.dataset | Downsampled from 68 to 68 cells
# [2020-11-04 21:52:39,784] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:39,809] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:39,811] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:39,813] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:39,815] INFO - scvi.dataset.dataset | Downsampled from 7 to 7 cells
# [2020-11-04 21:52:39,817] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:40,067] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:40,069] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:40,621] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:40,704] INFO - scvi.dataset.dataset | Downsampled from 1753 to 1753 cells
# [2020-11-04 21:52:40,713] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:41,100] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:41,102] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:41,977] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:42,111] INFO - scvi.dataset.dataset | Downsampled from 2829 to 2829 cells
# [2020-11-04 21:52:42,123] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:42,197] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:42,199] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:42,304] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:42,322] INFO - scvi.dataset.dataset | Downsampled from 362 to 362 cells
# [2020-11-04 21:52:42,327] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:42,804] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:42,806] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:43,875] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:44,043] INFO - scvi.dataset.dataset | Downsampled from 3531 to 3531 cells
# [2020-11-04 21:52:44,057] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:44,089] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:44,091] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:44,115] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:44,119] INFO - scvi.dataset.dataset | Downsampled from 78 to 78 cells
# [2020-11-04 21:52:44,122] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:44,338] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:44,340] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:44,780] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:44,849] INFO - scvi.dataset.dataset | Downsampled from 1456 to 1456 cells
# [2020-11-04 21:52:44,857] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:44,929] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:44,931] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:45,035] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:45,053] INFO - scvi.dataset.dataset | Downsampled from 361 to 361 cells
# [2020-11-04 21:52:45,057] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:45,091] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:45,093] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:45,134] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:45,140] INFO - scvi.dataset.dataset | Downsampled from 135 to 135 cells
# [2020-11-04 21:52:45,143] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:45,319] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:45,321] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:45,684] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:45,740] INFO - scvi.dataset.dataset | Downsampled from 1177 to 1177 cells
# [2020-11-04 21:52:45,747] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:45,921] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:45,923] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:46,264] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:46,319] INFO - scvi.dataset.dataset | Downsampled from 1177 to 1177 cells
# [2020-11-04 21:52:46,326] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:46,488] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:46,490] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:46,752] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:46,802] INFO - scvi.dataset.dataset | Downsampled from 1065 to 1065 cells
# [2020-11-04 21:52:46,809] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 21:52:46,981] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:46,983] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:47,355] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:47,410] INFO - scvi.dataset.dataset | Downsampled from 1170 to 1170 cells
# [2020-11-04 21:52:47,416] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-04 21:52:47,418] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-04 21:52:47,816] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-04 21:52:48,459] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:48,564] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:48,566] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:48,607] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:48,618] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:48,620] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:48,901] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:49,008] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:49,010] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:49,824] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:50,160] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:50,162] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:50,185] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:50,191] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:50,192] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:50,231] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:50,245] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:50,246] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:50,270] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:50,276] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:50,277] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:50,846] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:51,060] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:51,062] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:51,955] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:52,309] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:52,310] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:52,440] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:52,493] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:52,495] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:53,589] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:54,021] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:54,023] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:54,068] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:54,084] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:54,086] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:54,550] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:54,739] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:54,741] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:54,869] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:54,920] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:54,922] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:54,978] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:55,001] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:55,003] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:55,387] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:55,534] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:55,536] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:55,908] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:56,057] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:56,059] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:56,353] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:56,489] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:56,491] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:52:56,876] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 21:52:57,029] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:52:57,031] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:53:07,952] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 21:53:07,955] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 21:53:12,228] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id

# %%
#sample epithelial cells to get at most 1000 cells from each sample
subsampled_epithelial_cells = lpy.subsample(adata.obs["broad_celltypes"] == "Epithelial", 1000, adata.obs["SampleID"], doinspect=True)
# Out:
# Sample a subset of a defined size
# def subsample(truefalse_vector, subsamplesize, partition = None, doinspect = False):
#     if doinspect is True: print("\033Sample a subset of a defined size\033\033"); print(inspect.getsource(subsample));print("\033Execution:\033")
#     if partition is None:
#         partition = ["thesame" for x in range(len(truefalse_vector))]
#     valueset = list(set(partition))
#     fout = np.zeros(len(truefalse_vector), dtype="bool")
#     which = lambda lst:list(np.where(lst)[0])
#     for i in valueset:
#         subf = truefalse_vector & (partition == i)
#         wlts = which(subf)
#         if len(wlts) > subsamplesize:
#             wlts = random.sample(wlts, subsamplesize)
#         fout[wlts] = True
#     return(fout)
#
# Execution:

# %%
# Integrate the subsampled Epithelial cells fraction specifically
# uses the same method as before with identical parameters
das = lpy.scvi_prepare(adata, "SampleID", subsampled_epithelial_cells, nbgenes = 0, min_cell_threshold= 2)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "epithelial_subsample", "X_umap_epithelial_subsample", None, "leiden_epithelial_subsample_raw", cellnames = das["names"])
# Out:
# [2020-11-04 22:41:37,529] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:37,632] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:37,634] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:37,883] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:37,931] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:37,934] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:37,961] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:37,963] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:37,980] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:37,982] INFO - scvi.dataset.dataset | Downsampled from 50 to 50 cells
# [2020-11-04 22:41:37,985] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:38,071] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:38,073] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:38,341] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:38,379] INFO - scvi.dataset.dataset | Downsampled from 802 to 802 cells
# [2020-11-04 22:41:38,382] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:38,539] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:38,541] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:38,826] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:38,874] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:38,883] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:38,909] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:38,911] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:38,912] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:38,914] INFO - scvi.dataset.dataset | Downsampled from 3 to 3 cells
# [2020-11-04 22:41:38,916] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:38,946] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:38,948] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:38,965] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:38,968] INFO - scvi.dataset.dataset | Downsampled from 68 to 68 cells
# [2020-11-04 22:41:38,971] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:38,994] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:38,995] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:38,998] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:39,001] INFO - scvi.dataset.dataset | Downsampled from 7 to 7 cells
# [2020-11-04 22:41:39,003] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:39,161] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:39,163] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:39,469] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:39,516] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:39,525] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:39,681] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:39,683] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:39,985] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:40,032] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:40,041] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:40,089] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:40,091] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:40,186] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:40,200] INFO - scvi.dataset.dataset | Downsampled from 362 to 362 cells
# [2020-11-04 22:41:40,204] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:40,360] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:40,362] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:40,656] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:40,704] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:40,713] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:40,740] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:40,742] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:40,764] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:40,768] INFO - scvi.dataset.dataset | Downsampled from 78 to 78 cells
# [2020-11-04 22:41:40,771] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:40,930] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:40,932] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:41,228] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:41,275] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:41,284] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:41,332] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:41,333] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:41,428] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:41,442] INFO - scvi.dataset.dataset | Downsampled from 361 to 361 cells
# [2020-11-04 22:41:41,446] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:41,477] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:41,479] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:41,514] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:41,520] INFO - scvi.dataset.dataset | Downsampled from 135 to 135 cells
# [2020-11-04 22:41:41,523] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:41,681] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:41,683] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:41,982] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:42,030] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:42,039] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:42,196] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:42,198] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:42,480] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:42,526] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:42,535] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:42,687] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:42,689] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:42,931] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:42,979] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:42,988] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-04 22:41:43,144] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:43,146] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:43,459] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:43,505] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-04 22:41:43,513] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-04 22:41:43,515] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-04 22:41:43,902] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-04 22:41:44,194] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:44,312] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:44,314] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:44,350] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:44,361] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:44,363] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:44,633] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:44,735] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:44,737] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:45,047] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:45,178] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:45,180] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:45,201] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:45,206] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:45,208] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:45,243] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:45,256] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:45,258] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:45,279] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:45,285] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:45,286] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:45,610] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:45,742] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:45,744] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:46,067] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:46,198] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:46,200] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:46,316] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:46,364] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:46,366] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:46,683] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:46,814] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:46,816] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:46,860] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:46,875] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:46,877] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:47,195] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:47,334] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:47,336] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:47,451] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:47,499] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:47,501] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:47,556] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:47,576] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:47,578] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:47,899] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:48,031] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:48,033] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:48,341] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:48,473] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:48,475] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:48,750] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:48,882] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:48,883] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:49,214] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-04 22:41:49,347] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:49,349] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:51,767] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-04 22:41:51,769] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-04 22:41:53,617] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id

# %%
#in addition, insert leiden cluster with resolution 2 for the epithelial subsample
adata = lpy.insertLatent(adata,latent,None, None, None, "leidenres2_epithelial_subsample_raw", cellnames = adata.obs_names[subsampled_epithelial_cells], leiden_resolution=2)
# Out:
# defining permutation
# Finding clusters
# Inserting Cluster Id

# %%
#sample epithelial cells to get at most 1000 cells from each sample
subsampled_stromal_cells = lpy.subsample(adata.obs["broad_celltypes"] == "Stromal", 1000, adata.obs["SampleID"])

# %%
das = lpy.scvi_prepare(adata, "SampleID", subsampled_stromal_cells, nbgenes = 0, min_cell_threshold= 2)
latent = lpy.runSCVI(das["dataset"], n_latent= 16)
adata = lpy.insertLatent(adata,latent, "stromal_subsample", "X_umap_stromal_subsample", None, "leiden_stromal_subsample_raw", cellnames = das["names"])
adata = lpy.insertLatent(adata,latent,None, None, None, "leidenres2_stromal_subsample_raw", cellnames = das["names"],leiden_resolution=2)
# Out:
# [2020-11-11 13:20:54,691] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:54,856] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:54,858] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:55,141] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:55,189] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:55,195] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:55,349] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:55,351] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:55,635] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:55,685] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:55,691] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:55,846] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:55,848] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:56,090] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:56,138] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:56,144] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:56,214] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:56,216] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:56,305] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:56,322] INFO - scvi.dataset.dataset | Downsampled from 344 to 344 cells
# [2020-11-11 13:20:56,327] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:56,482] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:56,484] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:56,798] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:56,845] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:56,852] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:57,006] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:57,008] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:57,286] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:57,334] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:57,341] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:57,498] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:57,501] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:57,785] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:57,833] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:57,839] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:57,958] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:57,960] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:58,177] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:58,214] INFO - scvi.dataset.dataset | Downsampled from 736 to 736 cells
# [2020-11-11 13:20:58,219] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:58,250] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:58,252] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:58,276] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:58,279] INFO - scvi.dataset.dataset | Downsampled from 79 to 79 cells
# [2020-11-11 13:20:58,282] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:58,311] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:58,312] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:58,319] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:58,322] INFO - scvi.dataset.dataset | Downsampled from 24 to 24 cells
# [2020-11-11 13:20:58,324] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:58,393] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:58,395] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:58,483] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:58,497] INFO - scvi.dataset.dataset | Downsampled from 312 to 312 cells
# [2020-11-11 13:20:58,502] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:58,535] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:58,537] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:58,560] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:58,563] INFO - scvi.dataset.dataset | Downsampled from 82 to 82 cells
# [2020-11-11 13:20:58,567] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:58,726] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:58,729] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:59,015] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:59,063] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:59,069] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:59,222] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:59,224] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:59,508] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:20:59,556] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:20:59,562] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:20:59,714] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:20:59,717] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:20:59,999] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:00,046] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:21:00,053] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:21:00,208] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:00,210] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:00,488] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:00,537] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:21:00,544] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:21:00,697] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:00,699] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:00,988] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:01,036] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:21:01,042] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:21:01,117] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:01,119] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:01,238] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:01,258] INFO - scvi.dataset.dataset | Downsampled from 399 to 399 cells
# [2020-11-11 13:21:01,263] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:21:01,419] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:01,421] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:01,678] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:01,726] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:21:01,733] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:21:01,858] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:01,860] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:02,086] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:02,123] INFO - scvi.dataset.dataset | Downsampled from 755 to 755 cells
# [2020-11-11 13:21:02,129] INFO - scvi.dataset.anndataset | Dense size under 1Gb, casting to dense format (np.ndarray).
# [2020-11-11 13:21:02,283] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:02,285] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:02,582] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:02,633] INFO - scvi.dataset.dataset | Downsampled from 1000 to 1000 cells
# [2020-11-11 13:21:02,639] INFO - scvi.dataset.dataset | Merging datasets. Input objects are modified in place.
# [2020-11-11 13:21:02,641] INFO - scvi.dataset.dataset | Gene names and cell measurement names are assumed to have a non-null intersection between datasets.
# [2020-11-11 13:21:03,091] INFO - scvi.dataset.dataset | Keeping 28614 genes
# [2020-11-11 13:21:03,409] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:03,542] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:03,545] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:03,859] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:03,994] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:03,996] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:04,272] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:04,405] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:04,407] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:04,519] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:04,578] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:04,580] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:04,918] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:05,051] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:05,053] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:05,361] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:05,495] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:05,498] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:05,810] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:05,942] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:05,944] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:06,179] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:06,292] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:06,294] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:06,339] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:06,354] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:06,356] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:06,384] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:06,392] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:06,393] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:06,501] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:06,546] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:06,548] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:06,593] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:06,610] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:06,612] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:06,932] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:07,067] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:07,069] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:07,387] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:07,520] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:07,522] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:07,836] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:07,970] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:07,973] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:08,276] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:08,410] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:08,412] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:08,728] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:08,863] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:08,865] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:09,014] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:09,070] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:09,072] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:09,367] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:09,501] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:09,503] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:09,761] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:09,863] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:09,865] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:10,184] INFO - scvi.dataset.dataset | Computing the library size for the new data
# [2020-11-11 13:21:10,319] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:10,321] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:13,513] INFO - scvi.dataset.dataset | Remapping batch_indices to [0,N]
# [2020-11-11 13:21:13,516] INFO - scvi.dataset.dataset | Remapping labels to [0,N]
# [2020-11-11 13:21:16,102] INFO - scvi.inference.inference | KL warmup for 400 epochs
# HBox(children=(FloatProgress(value=0.0, description='training', max=500.0, style=ProgressStyle(description_wid…
# defining permutation
# Inserting Latent coords
# computing UMAP
# Inserting Umap coords
# Finding clusters
# Inserting Cluster Id
# defining permutation
# Finding clusters
# Inserting Cluster Id

# %%
adata.write_h5ad("N3-integrated_donors.h5ad")
# Out:
# ... storing 'leiden_stromal_subsample_raw' as categorical
# ... storing 'leidenres2_stromal_subsample_raw' as categorical
